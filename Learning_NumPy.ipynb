# %% [markdown]
# <a href="https://colab.research.google.com/github/Holy-Morphism/LearningNumpy/blob/main/Learning_NumPy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Import library numpy
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np

# %% [markdown]
# Create a numpy array

# %%
x = np.array([1,2,3,4])
print(x)
# Out:
# [1 2 3 4]

# %% [markdown]
# To check datatype

# %%
print(type(x))
# Out:
# <class 'numpy.ndarray'>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Creating a list

# %%
# %timeit [j**4 for j in range(1,9)]
# Out:
# 2.6 µs ± 55.5 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %% [markdown]
# With NumPy

# %%
# %timeit np.arange(1,9)**4
# Out:
# 5.15 µs ± 502 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %% [markdown]
# Numpay array takes less time to generate array

# %% [markdown]
# Create a numpy array

# %%
a = np.array([1,2,3])
print(a)
# Out:
# [1 2 3]

# %% [markdown]
# #Array

# %%
x=[1,2,3,4,5]
a = np.array(x)
print(a)
print(type(a))
# Out:
# [1 2 3 4 5]
# <class 'numpy.ndarray'>

# %%
l = []

for i in range(0,5):
    int_1 = int(input('Enter value : '))
    l.append(int_1)

print(np.array(l))
# Out:
# Enter value : 1
# Enter value : 2
# Enter value : 3
# Enter value : 4
# Enter value : 5
# [1 2 3 4 5]

# %% [markdown]
# To check dimension

# %%
w = np.array(l)

print(w.ndim)
# Out:
# 1

# %% [markdown]
# To create arrays of mulitple dimension

# %%
y =np.array(l,ndmin=10)
print(y)
print(y.ndim)
# Out:
# [[[[[[[[[[1 2 3 4 5]]]]]]]]]]
# 10
